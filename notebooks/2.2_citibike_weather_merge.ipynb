# %%
import pandas as pd
import numpy as np
import requests
import os
from datetime import datetime
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Create a folder to store raw data
os.makedirs('data/raw', exist_ok=True)

# Base URL of CitiBike 2022 data
base_url = 'https://s3.amazonaws.com/tripdata/'

# List of 2022 CSV filenames (monthly)
files = [
    "202201-citibike-tripdata.csv",
    "202202-citibike-tripdata.csv",
    "202203-citibike-tripdata.csv",
    "202204-citibike-tripdata.csv",
    "202205-citibike-tripdata.csv",
    "202206-citibike-tripdata.csv",
    "202207-citibike-tripdata.csv",
    "202208-citibike-tripdata.csv",
    "202209-citibike-tripdata.csv",
    "202210-citibike-tripdata.csv",
    "202211-citibike-tripdata.csv",
    "202212-citibike-tripdata.csv"
]

# Download each file if not already downloaded
for file in files:
    file_path = os.path.join('data/raw', file)
    if not os.path.exists(file_path):
        print(f"Downloading {file}...")
        r = requests.get(base_url + file)
        with open(file_path, 'wb') as f:
            f.write(r.content)
    else:
        print(f"{file} already exists.")
# Out:
# 202201-citibike-tripdata.csv already exists.
# 202202-citibike-tripdata.csv already exists.
# 202203-citibike-tripdata.csv already exists.
# 202204-citibike-tripdata.csv already exists.
# 202205-citibike-tripdata.csv already exists.
# 202206-citibike-tripdata.csv already exists.
# 202207-citibike-tripdata.csv already exists.
# 202208-citibike-tripdata.csv already exists.
# 202209-citibike-tripdata.csv already exists.
# 202210-citibike-tripdata.csv already exists.
# 202211-citibike-tripdata.csv already exists.
# 202212-citibike-tripdata.csv already exists.

# %%
# Notebook cell: list CSV files in current folder
import os, glob, pathlib
cwd = pathlib.Path.cwd()
print("Current working directory:", cwd)
csvs = list(cwd.glob("../data/raw/*.csv"))
print(f"Found {len(csvs)} csv file(s) in this folder:")
for f in csvs:
    print(" -", f.name)
# also print top-level filenames for quick glance
print("\nTop-level items:")
for p in cwd.iterdir():
    print(" ", p.name)
# Out:
# Current working directory: /Users/karen/Desktop/CF/citi-bike-nyc-2022-dashboard/notebooks
# Found 12 csv file(s) in this folder:
#  - JC-202203-citibike-tripdata.csv
#  - JC-202201-citibike-tripdata.csv
#  - JC-202209-citibike-tripdata.csv
#  - JC-202211-citibike-tripdata.csv
#  - JC-202207-citbike-tripdata.csv
#  - JC-202205-citibike-tripdata.csv
#  - JC-202202-citibike-tripdata.csv
#  - JC-202208-citibike-tripdata.csv
#  - JC-202206-citibike-tripdata.csv
#  - JC-202210-citibike-tripdata.csv
#  - JC-202204-citibike-tripdata.csv
#  - JC-202212-citibike-tripdata.csv
#
# Top-level items:
#   citi_dashboard_Part_2.py
#   citi_dashboard.py
#   2.2_citibike_weather_merge.ipynb
#   Configurations.ipynb
#   2.6_Creating Dashboards with Python.ipynb
#   2.4_fundamentals_of_visualization_libraries_part_2.ipynb
#   2.5_advanced_geospatial_plotting.ipynb
#   2.3_fundamentals_of_visualization_libraries_Part 1.ipynb

# %%
# Read and combine all monthly CSVs
all_data = []

for file in csvs:
    df = pd.read_csv(os.path.join('data/raw', file))
    all_data.append(df)

# Combine into a single DataFrame
citi_bike_df = pd.concat(all_data, ignore_index=True)

# Check the first few rows
citi_bike_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17  2022-03-18 15:45:34
# 1  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48  2022-03-04 16:50:45
# 2  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32  2022-03-13 17:54:44
# 3  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47  2022-03-13 15:41:22
# 4  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18  2022-03-11 12:33:24
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1                   Baldwin at Montgomery            JC020
# 2                   Baldwin at Montgomery            JC020
# 3                   Baldwin at Montgomery            JC020
# 4                   Baldwin at Montgomery            JC020
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743140
# 1                                 Grove St PATH          JC005  40.723659
# 2                                 Grove St PATH          JC005  40.723659
# 3                                 Grove St PATH          JC005  40.723659
# 4                                 Grove St PATH          JC005  40.723659
#
#    start_lng    end_lat    end_lng member_casual
# 0 -74.040041  40.736982 -74.027781        casual
# 1 -74.064194  40.719586 -74.043117        member
# 2 -74.064194  40.719586 -74.043117        member
# 3 -74.064194  40.719586 -74.043117        member
# 4 -74.064194  40.719586 -74.043117        member

# %%
citi_bike_df.to_csv("../data/processed/citibike_with_weather_merged.csv",index=False)
citi_bike_df['date'] = pd.to_datetime(citi_bike_df['started_at']).dt.date
citi_bike_df.shape
# Out:
# (895485, 14)

# %%
from calendar import monthrange

token = ""
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"
headers = {"token": token}

# %%
all_results = []

for month in range(1, 13):
    startdate = f"2022-{month:02d}-01"
    last_day = monthrange(2022, month)[1]
    enddate = f"2022-{month:02d}-{last_day}"

    params = {
        "datasetid": "GHCND",
        "stationid": "GHCND:USW00014732",  # LaGuardia
        "datatypeid": "TAVG",
        "startdate": startdate,
        "enddate": enddate,
        "units": "metric",
        "limit": 1000
    }

    r = requests.get(url, headers=headers, params=params)
    r.raise_for_status()

    data = r.json().get("results", [])
    all_results.extend(data)
# Out:
# Weather data fetched successfully!

# %%
# Concatenate into DataFrame
weather_data = pd.DataFrame(all_results)

# Parse date
weather_data["date"] = pd.to_datetime(weather_data["date"])

# Keep only needed columns
weather_data = weather_data[["date", "value"]].rename(columns={"value": "avgTemp"})

# Sort for sanity
weather_data = weather_data.sort_values("date").reset_index(drop=True)

print(df.head())
print(df.tail())

# %%
# Save to CSV
os.makedirs('data/processed', exist_ok=True)
weather_data.to_csv('data/processed/la_guardia_weather_2022.csv', index=False)

# %% [markdown]
# ## Merging with local files

# %%
#! Attention -- Load and inspect the saved weather data
weather_df = pd.read_csv('../data/processed/la_guardia_weather_2022.csv', parse_dates=['date'])
print(weather_df.shape)
weather_df.head()
# Out:
# (1000, 5)
#         date datatype            station attributes    value
# 0 2022-01-01     ADPT  GHCND:USW00014732       ,,W,    100.0
# 1 2022-01-01     ASLP  GHCND:USW00014732       ,,W,  10078.0
# 2 2022-01-01     ASTP  GHCND:USW00014732       ,,W,  10078.0
# 3 2022-01-01     AWBT  GHCND:USW00014732       ,,W,    106.0
# 4 2022-01-01     AWND  GHCND:USW00014732       ,,W,      2.8

# %%
# keep only average temperature data
df_temps = weather_df[weather_df['datatype']=='TAVG']
df_temps = df_temps.copy()
df_temps["date"] = pd.to_datetime(df_temps["date"]).dt.date
df_temps.rename(columns={"value":"avgTemp"}, inplace=True)
df_temps.drop(columns=['datatype','station','attributes'], inplace=True)


df_temps
# Out:
#            date  avgTemp
# 11   2022-01-01     11.6
# 30   2022-01-02     11.4
# 49   2022-01-03      1.4
# 67   2022-01-04     -2.7
# 85   2022-01-05      3.2
# 105  2022-01-06      4.9
# 123  2022-01-07      0.7
# 142  2022-01-08     -2.5
# 160  2022-01-09      1.4
# 178  2022-01-10      1.6
# 196  2022-01-11     -5.4
# 214  2022-01-12     -1.9
# 232  2022-01-13      4.0
# 250  2022-01-14      4.8
# 268  2022-01-15     -6.7
# 286  2022-01-16     -8.0
# 305  2022-01-17      3.9
# 325  2022-01-18      1.8
# 343  2022-01-19      3.2
# 362  2022-01-20      5.1
# 381  2022-01-21     -6.0
# 399  2022-01-22     -5.9
# 417  2022-01-23     -0.7
# 436  2022-01-24     -0.2
# 455  2022-01-25      3.6
# 474  2022-01-26     -2.3
# 492  2022-01-27     -4.2
# 510  2022-01-28      0.1
# 530  2022-01-29     -4.8
# 551  2022-01-30     -7.1
# 569  2022-01-31     -3.4
# 587  2022-02-01     -1.7
# 605  2022-02-02      2.3
# 625  2022-02-03      6.4
# 646  2022-02-04      5.8
# 666  2022-02-05     -2.8
# 684  2022-02-06     -4.8
# 702  2022-02-07      0.5
# 723  2022-02-08      4.1
# 742  2022-02-09      2.8
# 760  2022-02-10      6.3
# 780  2022-02-11      8.6
# 798  2022-02-12     11.8
# 816  2022-02-13      2.8
# 836  2022-02-14     -4.3
# 854  2022-02-15     -4.7
# 872  2022-02-16      1.6
# 890  2022-02-17     11.6
# 909  2022-02-18      9.9
# 927  2022-02-19      0.1
# 945  2022-02-20     -2.6
# 963  2022-02-21      4.1
# 981  2022-02-22      5.6

# %%
# Merge on date
merged_df = pd.merge(citi_bike_df, df_temps, on='date', how='left')

# Save merged CSV
merged_df.to_csv('../data/processed/citi_bike_with_weather_2022.csv', index=False)
merged_df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  3255D3E3F33CDC45   classic_bike  2022-03-18 15:38:17  2022-03-18 15:45:34
# 1  17FA5604A37338F9  electric_bike  2022-03-04 16:44:48  2022-03-04 16:50:45
# 2  7DEC9ADDB8D6BBE1  electric_bike  2022-03-13 17:44:32  2022-03-13 17:54:44
# 3  9D69F74EEF231A2E   classic_bike  2022-03-13 15:33:47  2022-03-13 15:41:22
# 4  C84AE4A9D78A6347   classic_bike  2022-03-11 12:21:18  2022-03-11 12:33:24
#
#                        start_station_name start_station_id  \
# 0  Mama Johnson Field - 4 St & Jackson St            HB404
# 1                   Baldwin at Montgomery            JC020
# 2                   Baldwin at Montgomery            JC020
# 3                   Baldwin at Montgomery            JC020
# 4                   Baldwin at Montgomery            JC020
#
#                                end_station_name end_station_id  start_lat  \
# 0  South Waterfront Walkway - Sinatra Dr & 1 St          HB103  40.743140
# 1                                 Grove St PATH          JC005  40.723659
# 2                                 Grove St PATH          JC005  40.723659
# 3                                 Grove St PATH          JC005  40.723659
# 4                                 Grove St PATH          JC005  40.723659
#
#    start_lng    end_lat    end_lng member_casual        date  avgTemp
# 0 -74.040041  40.736982 -74.027781        casual  2022-03-18      NaN
# 1 -74.064194  40.719586 -74.043117        member  2022-03-04      NaN
# 2 -74.064194  40.719586 -74.043117        member  2022-03-13      NaN
# 3 -74.064194  40.719586 -74.043117        member  2022-03-13      NaN
# 4 -74.064194  40.719586 -74.043117        member  2022-03-11      NaN

# %% [markdown]
# **Data sources**
# - CitiBike trip data (2022) — raw CSV files per month/period (downloaded from S3).
# - NOAA daily weather (LaGuardia station) — daily average temperature for 2022 (obtained via NOAA API).
#
# **What\s the Task Here**
# - Combined all CitiBike 2022 CSVs into a single DataFrame using a memory-efficient pattern:
#   `pd.concat((pd.read_csv(f) for f in filepaths), ignore_index=True)`.
# - Retrieved daily avg temperature (TAVG) for LaGuardia via NOAA API, converted values from tenths of °C to °C.
# - Created `date` columns in both datasets (CitiBike: from `start_time`; NOAA: parsed datetimes), and merged by `date` using a left join:
#   `df_merged = df.merge(df_temps, how='left', on='date', indicator=True)`.
# - Saved a merged CSV locally: `data/processed/citibike_nyc_2022_with_weather.csv`.
#
# **Relationship & what achieved**
# - The merged dataset attaches daily weather (avg temperature) to each bike trip, enabling analysis of how temperature correlates with ridership (seasonality, peaks).
# - With this merged data we can now create strategic visualizations: top stations (bar charts), monthly trips vs temperature (line charts), and geospatial route analysis (maps). This completes the data-prep stage; next step is to build interactive visuals/dashboards.
#
# **Notes**
# - Large raw / processed data files are excluded from the Git repo (`.gitignore` includes `data/`) to respect GitHub size limits. The notebooks and sample outputs are included in the repository.
